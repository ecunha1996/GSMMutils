# %%
from gsmmutils.model.COBRAmodel import *
from gsmmutils import DATA_PATH
import logging
logging.getLogger("cobra").setLevel(logging.CRITICAL)
import warnings
warnings.filterwarnings("ignore")
from cobra.flux_analysis import flux_variability_analysis as fva

# %%
model = MyModel(join(DATA_PATH, 'models/model_ng.xml'), 'e_Biomass__cytop')
model.exchanges.EX_C00011__dra.lower_bound = -1.466
model.exchanges.EX_C00205__dra.lower_bound = -16
model.slim_optimize()
# Out:
# Loading
# Reactions: 4519
# Metabolites: 4000
# Genes: 1281
# Model loaded
# 0.029241604698782404

# %%
model.summary()
# Out:
# Running pFBA
# <h3>Objective</h3><p>1.0 e_Biomass__cytop = 0.03556264628096722</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__extr</td>
#       <td>EX_C00001__dra</td>
#       <td>1.204</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr</td>
#       <td>EX_C00009__dra</td>
#       <td>0.005611</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011__extr</td>
#       <td>EX_C00011__dra</td>
#       <td>1.466</td>
#       <td>1</td>
#       <td>99.91%</td>
#     </tr>
#     <tr>
#       <td>C00059__extr</td>
#       <td>EX_C00059__dra</td>
#       <td>0.003942</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00080__extr</td>
# ...

# %%
from cobra.flux_analysis import flux_variability_analysis as fva
fva(model, ["R02098__cytop"], fraction_of_optimum=0.0)
# Out:
#                minimum   maximum
# R02098__cytop      0.0  6.633151

# %%
model.test_reaction("R01665__cytop")
# Out:
#              Flux ReactantOrProduct
# dCMP     0.000000          Reactant
# ATP      0.120210          Reactant
# H+    1012.028352          Reactant
# ADP      0.122790           Product
# dCDP     0.000102           Product

# %%
published = MyModel(r"C:\Users\Bisbii\OneDrive - Universidade do Minho\Models\nsalina_published_lv3.xml", "Biomass_Nanno_mixo")
blocked_published = find_blocked_reactions(published, open_exchanges=True, processes=6)
len(blocked_published)/len(published.reactions)
# Out:
# Loading
# Reactions: 2345
# Metabolites: 1985
# Genes: 911
# Model loaded
# 0.3471215351812367

# %%
from cobra.flux_analysis import find_blocked_reactions
model = MyModel(join(DATA_PATH, 'models/model_ng.xml'), 'e_Biomass__cytop')
blocked = find_blocked_reactions(model, open_exchanges=True, processes=6)
print(len(blocked)/len(model.reactions))   # 0.2586
model.exchanges.EX_C00011__dra.lower_bound = -0.67
model.slim_optimize()
# Out:
# Loading
# Reactions: 4521
# Metabolites: 4004
# Genes: 1281
# Model loaded
# 0.25857111258571114
# 0.014326612769070582

# %%
model.test_reaction("e_Cofactor__cytop")
# Out:
#                                                  Flux ReactantOrProduct
# (R)-Lipoate                                  0.083750          Reactant
# [2Fe-2S] without apo protein                38.696314          Reactant
# NADP+                                        0.031905          Reactant
# Heme                                         0.019706          Reactant
# Tetrahydrofolate                             0.035263          Reactant
# Ubiquinol-9                                  0.012407          Reactant
# FAD                                          0.024815          Reactant
# Biotin                                       0.047857          Reactant
# Glutathione                                  0.067000          Reactant
# Thiamin diphosphate                          0.051538          Reactant
# 10-Formyltetrahydrofolate                    0.033500          Reactant
# NAD+                                         0.031905          Reactant
# ...

# %%
enzyme_reactions_map = {}
for reaction in model.reactions:
    if "ec-code" in reaction.annotation:
        for ec in reaction.annotation["ec-code"]:
            if ec not in enzyme_reactions_map:
                enzyme_reactions_map[ec] = []
            enzyme_reactions_map[ec].append(reaction.id)

# %%
for reaction in blocked:
    if "ec-code" in model.reactions.get_by_id(reaction).annotation:
        if isinstance(model.reactions.get_by_id(reaction).annotation["ec-code"], str):
            annotation = [model.reactions.get_by_id(reaction).annotation["ec-code"]]
        else:
            annotation = model.reactions.get_by_id(reaction).annotation["ec-code"]
        for ec in annotation:
            if ec in enzyme_reactions_map.keys() and len(enzyme_reactions_map[ec]) > 5 and ec not in ["1.3.1.10", "2.3.1.86", "1.1.1.100"]:
                print(ec, reaction)
# Out:
# 3.1.3.5 R01569__cytop
# 4.4.1.1 R04770__cytop
# 6.2.1.3 FACOAL202__chlo
# 4.4.1.13 R04941__mito
# 4.4.1.13 R02408__cytop
# 4.4.1.1 R02408__cytop
# 1.3.3.6 R07896__pero
# 4.4.1.13 R09366__mito
# 4.4.1.1 R09366__mito
# 4.4.1.13 R02408__mito
# 4.4.1.1 R02408__mito
# 3.1.3.5 R02088__cytop
# 3.1.3.5 R01664__cytop
# 3.1.3.5 R02102__cytop
# 3.1.1.4 BMGR6234__cytop
# 2.3.1.43 BMGR6234__cytop
# 6.2.1.3 FACOAL200__er
# 4.4.1.13 R01286__chlo
# 3.1.3.5 R01968__cytop
# 4.4.1.13 R04941__cytop
# 3.6.1.5 R00961__cytop
# 6.2.1.2 R01176__pero
# 6.2.1.3 FACOAL200__chlo
# 6.2.1.3 FACOAL183y__chlo
# 3.1.1.4 BMGR6233__cytop
# 2.3.1.43 BMGR6233__cytop
# 1.3.3.6 R07892__pero
# 3.1.1.4 BMGR6238__cytop
# 2.3.1.43 BMGR6238__cytop
# 4.4.1.13 R09366__cytop
# 4.4.1.1 R09366__cytop
# 1.3.3.6 R07888__pero
# 2.3.1.85 R04535__mito

# %%
# model = MyModel(join(DATA_PATH, 'models/model_ng.xml'), 'e_Biomass__cytop')
# model.exchanges.EX_C05684__dra.bounds  = (-1000, 1000)
model.test_reaction("R11861__cytop")
# Out:
#                      Flux ReactantOrProduct
# Glutathione     12.720771          Reactant
# Cys-Gly       1723.295739           Product
# 5-Oxoproline   901.922700           Product

# %%
check_balance(model)
# Out:
# {}

# %%
# model.create_demand("C00365__mito")
fva(model, ["R00497__chlo"], fraction_of_optimum=0.0)
# Out:
#               minimum     maximum
# R00497__chlo      0.0  151.154058

# %%
model.create_demand("C00006__chlo")
# Out:
# <Reaction DM_C00006__chlo at 0x292a20b0190>

# %%
for met in model.metabolites:
    if len(met.reactions) == 1 and [r for r in met.reactions][0].id.startswith("T"):
        print(met.id, met.name)
# Out:
# C02990__mito L-Palmitoylcarnitine
# C00318__mito L-Carnitine
# C00668__er alpha-D-Glucose 6-phosphate
# C01172__er beta-D-Glucose 6-phosphate
# C00076__er Calcium cation
# C01190__cytop Glucosylceramide
# C00777__cytop Retinoate
# C02990__cytop L-Palmitoylcarnitine
# C00318__cytop L-Carnitine
# C00035__chlo GDP
# C01330__pero Sodium cation
# C01330__vacu Sodium cation
# C00123__vacu L-Leucine
# C05512__vacu Deoxyinosine
# C00299__vacu Uridine
# C00294__vacu Inosine
# C00076__vacu Calcium cation
# C00407__vacu L-Isoleucine
# C00064__vacu L-Glutamine
# C00387__vacu Guanosine
# C00082__vacu L-Tyrosine
# C00214__vacu Thymidine
# C01762__vacu Xanthosine
# C00475__vacu Cytidine
# C00212__vacu Adenosine
# C00330__vacu Deoxyguanosine
# C00152__vacu L-Asparagine
# C00881__vacu Deoxycytidine
# C00559__vacu Deoxyadenosine
# C00526__vacu Deoxyuridine
# C00029__golg UDP-glucose
# C00307__golg CDP-choline

# %%
model.test_reaction("DGTSS_140_161__er")
# Out:
#                                                            Flux  \
# Diacylglycerolhomoserine (14:0:16:1(9Z))               0.000000
# S-Adenosyl-L-methionine                                0.000000
# S-Adenosyl-L-homocysteine                            587.198632
# Diacylglyceryl-N,N,N-trimethylhomoserine (14:0/...     0.000000
# H+                                                  1021.321606
#
#                                                    ReactantOrProduct
# Diacylglycerolhomoserine (14:0:16:1(9Z))                    Reactant
# S-Adenosyl-L-methionine                                     Reactant
# S-Adenosyl-L-homocysteine                                    Product
# Diacylglyceryl-N,N,N-trimethylhomoserine (14:0/...           Product
# H+                                                           Product

# %%
from cobra.flux_analysis import flux_variability_analysis as fva
fva(model, ["T_PI182tr__er"], fraction_of_optimum=0.0)
# Out:
#                minimum  maximum
# T_PI182tr__er      0.0      0.0

# %%
from gsmmutils.utils.utils import get_biomass_mass

1-(5Z,8Z,11Z,14Z-eicosatetraenoyl)-sn-glycero-3-phosphocholine
model = MyModel(r"C:\Users\Bisbii\Downloads\model.xml", 'e_Biomass__cytop')
# Out:
# Loading
# Reactions: 2630
# Metabolites: 2175
# Genes: 1309
# Model loaded

# %%
lipid_subreactions = [model.reactions.e_Triacylglycerol__er, model.reactions.e_Phosphatidylethanolamine__er, model.reactions.e_Phosphatidylcholine__er,
         model.reactions.e_Phosphatidylinositol__er, model.reactions.e_Phosphatidylglycerol__chlo, model.reactions.e_Digalactosyldiacylglycerol__chlo,
         model.reactions.e_Sulfoquinovosyldiacylglycerol__chlo, model.reactions.e_Monogalactosyldiglycerol__chlo]
get_biomass_mass(model, lipid_subreactions=lipid_subreactions)
# Out:
# e-Lipid
# 0.0339344965596954
# e_Pigment__chlo
# (0.03118, {'C': 4.065504968320402, 'N': 0.005311237970556001, 'O': 0.5861271946719604, 'P': 0.011587487994567722, 'S': 0.0007859750492159999, 'H': 6.3975989888612474})
# e_RNA__cytop
# (0.14543, {'C': 7.1750176083204025, 'N': 1.2556625979705558, 'O': 4.47254959467196, 'P': 0.7946767679945677, 'S': 0.0007859750492159999, 'H': 10.494373388861247})
# e_Carbohydrate__cytop
# (0.17919, {'C': 14.527060574720403, 'N': 1.2557831031705557, 'O': 9.51718816699196, 'P': 0.7947274031945679, 'S': 0.0007859750492159999, 'H': 20.583416592301244})
# e_DNA__cytop
# (0.001, {'C': 14.558429999720405, 'N': 1.2680272461705557, 'O': 9.53668749199196, 'P': 0.797956206194568, 'S': 0.0007859750492159999, 'H': 20.622849769301244})
# e_Cofactor__cytop
# (0.01044, {'C': 14.993557606920403, 'N': 1.3473350472705554, 'O': 9.677741919791957, 'P': 0.808779636394568, 'S': 0.018375162049216003, 'H': 21.216783586701244})
# e_Protein__cytop
# ...

# %%
check_balance(model)
# Out:
# {'R12183__cytop': {'C': -11.0, 'H': -14.0, 'N': -4.0, 'O': -2.0, 'Hr': -1.0},
#  'R12120__cytop': {'C': -11.0, 'H': -10.0, 'O': -2.0, 'Hr': -1.0, 'N': -4.0},
#  'R12120__er': {'C': -11.0, 'H': -10.0, 'Hr': -1.0, 'N': -4.0, 'O': -2.0},
#  'R02488__pero': {'H': -1.0},
#  'R12118__cytop': {'C': -33.0, 'H': -30.0, 'O': -6.0, 'Hr': -3.0, 'N': -12.0},
#  'R02874__er': {'C': -11.0, 'H': -10.0, 'Hr': -1.0, 'N': -4.0, 'O': -2.0},
#  'R12118__er': {'C': -33.0, 'H': -30.0, 'Hr': -3.0, 'N': -12.0, 'O': -6.0},
#  'R05724__chlo': {'H': -2.0},
#  'R12429__mito': {'H': 1.0},
#  'R02003__chlo': {'H': -1.0},
#  'R05725__chlo': {'H': -2.0},
#  'R00847__pero': {'H': -1.0},
#  'R12429__chlo': {'H': 1.0},
#  'R00466__cytop': {'H': -1.0},
#  'R12121__er': {'C': -11.0, 'H': -10.0, 'O': -2.0, 'Hr': -1.0, 'N': -4.0},
#  'R01711__chlo': {'H': -1.0},
#  'R12121__cytop': {'O': -2.0, 'C': -11.0, 'H': -10.0, 'Hr': -1.0, 'N': -4.0},
#  'R07412__mito': {'H': -4.0, 'N': -2.0, 'R': -2.0},
# ...

# %%
reactions = [ key for key in check_balance(model).keys()]

# %%
model.optimize()[reactions]
# Out:
# R12183__cytop    0.000000
# R12120__cytop    0.000000
# R12120__er       0.000000
# R02488__pero     0.000000
# R12118__cytop    0.000000
# R02874__er       0.000000
# R12118__er       0.000000
# R05724__chlo     0.000000
# R12429__mito     0.000000
# R02003__chlo     0.034099
# R05725__chlo     0.000000
# R00847__pero     0.000000
# R12429__chlo     0.000000
# R00466__cytop    0.002993
# R12121__er       0.000000
# R01711__chlo     0.000000
# R12121__cytop    0.000000
# R07412__mito     0.000000
# R05731__er       0.000000
# R08157__chlo     0.000000
# R09250__chlo     0.000192
# R01658__chlo     0.034291
# Name: fluxes, dtype: float64

# %%
model.summary()
# Out:
# Running pFBA
# <h3>Objective</h3><p>1.0 e_Biomass__cytop = 0.25209776961319996</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__extr</td>
#       <td>EX_C00001__extr</td>
#       <td>7.763</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr</td>
#       <td>EX_C00009__extr</td>
#       <td>0.2038</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011__extr</td>
#       <td>EX_C00011__extr</td>
#       <td>11</td>
#       <td>1</td>
#       <td>99.92%</td>
#     </tr>
#     <tr>
#       <td>C00059__extr</td>
#       <td>EX_C00059__extr</td>
#       <td>0.043</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00080__extr</td>
# ...

# %%
for reaction in blocked:
    if reaction.endswith("cytop") and any("R" in met.formula for met in model.reactions.get_by_id(reaction).metabolites if met.formula): # not reaction.startswith("R") and 
        print(reaction, model.reactions.get_by_id(reaction).name)

# %%
model.test_reaction("R01021__cytop")
# Out:
#                           Flux ReactantOrProduct
# Choline               0.000000          Reactant
# ATP                  13.872638          Reactant
# ADP                  13.471335           Product
# Choline phosphate     0.119489           Product
# H+                 2369.676333           Product

# %%
model.create_demand("C00042__nucl")
# Out:
# <Reaction DM_C00042__nucl at 0x18ea76ac310>

# %%
lipids_reactions = ["e_TAG__lip", "e_PG__chlo", "e_PE__er", "e_PC__er", "e_PI__er", "e_DGDG__chlo", "e_MGDG__chlo", "e_SQDG__chlo", "e_DAG__er", "e_DGTS__er"]
acyl_in_model = []
to_remove = []
for lipids_reaction in lipids_reactions:
    bio_reaction = model.reactions.get_by_id(lipids_reaction)
    for reactant in bio_reaction.reactants:
        if reactant.id.startswith("BMGC"):
            acyl = reactant.name.split("-sn")[0]
            acyl_in_model.append(acyl)
for metabolite in model.metabolites:
    if metabolite.id.startswith("BMGC") and metabolite.id.endswith("chlo"):
        name = metabolite.name.split("-sn")[0]
        if name not in acyl_in_model:
            for reaction in metabolite.reactions:
                if reaction.id in blocked and reaction.id.endswith("chlo"):
                    to_remove.append(reaction.id)

# %%
with open(join(DATA_PATH, "models", "to_remove.txt"), "w") as f:
    for reaction in to_remove:
        if "_V" not in reaction:
            f.write('"'+reaction.split("__")[0]+'",\n')

# %%
model = MyModel(join(DATA_PATH, 'models/model_ng.xml'), 'e_Biomass__cytop')
# validator = ModelValidator(model)
# model.reactions.ATPm__cytop.bounds = (0, 1000)
model.summary(pfba=False)
# Out:
# Loading
# Reactions: 4749
# Metabolites: 4495
# Genes: 1286
# Model loaded
# <h3>Objective</h3><p>1.0 e_Biomass__cytop = 2.310779994655426</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00001__extr</td>
#       <td>EX_C00001__dra</td>
#       <td>64.32</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00009__extr</td>
#       <td>EX_C00009__dra</td>
#       <td>0.4145</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011__extr</td>
#       <td>EX_C00011__dra</td>
#       <td>108</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>C00014__extr</td>
#       <td>EX_C00014__dra</td>
#       <td>11.15</td>
#       <td>0</td>
#       <td>0.00%</td>
# ...

# %%
model.revert_reaction("R00432__mito")
model.test_reaction("R00432__mito")
# Out:
#                        Flux
# Succinyl-CoA       4.904052
# GDP                0.000000
# Orthophosphate  1000.000000

# %%
model.create_sink("C15811__chlo")
model.create_sink("C00138__chlo")
print(model.test_reaction("I2FE2SR__chlo"))
# Out:
#                                                 Flux
# [Enzyme]-S-sulfanylcysteine                91.126713
# [2Fe-1S] desulfurated iron-sulfur cluster   0.000000

# %%
# model.create_sink("C00229__mito")
# model.create_sink("C00138__mito")
# model.create_sink("C22158__mito")
model.test_reaction("EX_C00899__dra")
# Out:
#                 Flux
# 11-cis-Retinol   0.0

# %%
model.metabolites.C22155__chlo.summary()
# Out:
# <h3>C22155__chlo</h3><p>S2Fe2As</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50.00%</td>
#       <td>2.311E-07</td>
#       <td>R12423__chlo</td>
#       <td>2.0 C00019__chlo + 2.0 C00080__chlo + 2.0 C00138__chlo + C22154__chlo + C22160__chlo --&gt; 2.0 C00073__chlo + 2.0 C00139__chlo + 2.0 C05198__chlo + 2.0 C14818__chlo + C15973__chlo + C22155__chlo</td>
#     </tr>
#     <tr>
#       <td>50.00%</td>
#       <td>2.311E-07</td>
#       <td>RXN_14390__chlo</td>
#       <td>MNXM147924__chlo + MNXM148911__chlo --&gt; C00009__chlo + C22155__chlo + MNXM147923__chlo + MNXM148054__chlo</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
# ...

# %%
sol = m.optimize()

# %%
# m = MyModel(join(DATA_PATH, 'models/model_with_trials.xml'), 'e_Biomass__cytop')
m.metabolites.C22155__chlo.summary(sol)
# Out:
# <h3>C22155__chlo</h3><p>S2Fe2As</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>31.51%</td>
#       <td>0.0008955</td>
#       <td>R12423__chlo</td>
#       <td>2.0 C00019__chlo + 2.0 C00080__chlo + 2.0 C00138__chlo + C22154__chlo + C22160__chlo --&gt; 2.0 C00073__chlo + 2.0 C00139__chlo + 2.0 C05198__chlo + 2.0 C14818__chlo + C15973__chlo + C22155__chlo</td>
#     </tr>
#     <tr>
#       <td>68.49%</td>
#       <td>0.001946</td>
#       <td>RXN_14390__chlo</td>
#       <td>MNXM147924__chlo + MNXM148911__chlo --&gt; C00009__chlo + C22155__chlo + MNXM147923__chlo + MNXM148054__chlo</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
# ...

# %%
# model.create_demand("C00116__chlo")
from cobra.flux_analysis import flux_variability_analysis as fva
fva(model, ["R12427__mito"], fraction_of_optimum=0.0)
# Out:
#               minimum  maximum
# R12427__mito      0.0      0.0

# %%
from cobra.flux_analysis import find_blocked_reactions
blocked = find_blocked_reactions(model, open_exchanges=True, processes=6)
from gsmmutils import DATA_PATH
with open(join(DATA_PATH, "blocked_reactions.txt"), "w") as f:
    for reaction in blocked:
        f.write(str(reaction) + "\n")
len(blocked)
# Out:
# 1868

# %%
# 1871
# Out:
# 1864

# %%
for reaction in model.reactions:
    if "ec-code" in reaction.annotation and "1.14.14.1" in reaction.annotation["ec-code"]:
        if reaction.id not in blocked:
            print(reaction.id)
# Out:
# R02874__er
# RXN_11881__er

# %%
c=0
for reaction in model.reactions:
    reactants_ids = [e.id.split("__")[0] for e in reaction.reactants]
    products_ids = [e.id.split("__")[0] for e in reaction.products]
    if any([e in reactants_ids for e in products_ids]) and not reaction.id.startswith("T"):
        print(reaction.id)
        c+=1
c
# Out:
# R04744__mito
# R05506__mito
# R03346__cytop
# R03089__er
# R01457__er
# R01185__mito
# R08091__mito
# R00494__pero
# R06526__er
# R09405__er
# R06522__chlo
# R07606__chlo
# R03968__mito
# ATPase__chlo
# R07050__er
# R01185__golg
# R08286__cytop
# R08409__chlo
# R05223__er
# R07765__mito
# R07080__er
# R01325__mito
# R02088__cytop
# R07603__mito
# R07604__mito
# R01186__golg
# R00402__cytop
# R02102__cytop
# R00183__cytop
# R07486__er
# R08294__er
# R01187__cytop
# ATP_Synthase__mitmem
# R09424__er
# Cytochrome_C_Reductase__mitmem
# R06896__chlo
# R01186__chlo
# R03223__chlo
# R02383__cytop
# R04961__mito
# R07046__er
# R00985__chlo
# R07001__er
# R08091__pero
# R12067__mito
# R00939__cytop
# R10057__er
# R10712__chlo
# R07051__er
# R09514__cytop
# R01900__mito
# R00829__pero
# R01187__mito
# R11312__chlo
# R06520__chlo
# R08767__mito
# R07409__mito
# R00209__mito
# R02719__cytop
# R01398__cytop
# R00940__cytop
# R11894__cytop
# R05259__er
# R07099__er
# R01082__mito
# R07601__mito
# ...

# %%
model = MyModel(join(DATA_PATH, 'models/model_ng.xml'), 'e_Biomass__cytop')
# Out:
# Loading
# Reactions: 4912
# Metabolites: 4814
# Genes: 1283
# Model loaded

# %%
balance = check_balance(model)
len(balance.keys())
# Out:
# 0

# %%
balance
# Out:
# {}

# %%
for met in model.reactions.BMGR6162_V12__chlo.metabolites:
    print(met.id, met.formula)
# Out:
# C05761__chlo C25H47N2O8PSCp
# BMGC419__chlo C23H37O7P
# C00229__chlo C11H21N2O7PSCp
# BMGC29537__chlo C37H61O8P

# %%
model = MyModel(r"C:\Users\Bisbii\OneDrive - Universidade do Minho\Models\iCre1355_auto.xml", 'Biomass_Chlamy_auto')
# Out:
# Loading
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_h "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_m "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_x "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthfglu_L_c "10-Formyltetrahydrofolyl L-glutamate">
# ...

# %%
model = MyModel(r"C:\Users\Bisbii\OneDrive - Universidade do Minho\Models\Model_Photoautotrophy.xml", 'Biomass_Cvu_auto_DASH_')
# Out:
# Loading
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_10fthf_h "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_h "10-Formyltetrahydrofolate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_10fthf_m "10-Formyltetrahydrofolate">
# ...

# %%
rna = {"atp_c", "utp_c", "gtp_c", "ctp_c"}
dna = {"datp_c", "dttp_c", "dgtp_c", "dctp_c"}
carbs = {"starch300_h", "man_c", "arab_L_c", "gal_c", "arab_DASH_L_c", "glc_DASH_A_c", "man_c"}
acids = {"ac_c", "but_c", "glyc_c", "ppa_c"}
pigments = {"chla_u", "chlb_u",  "acaro_h", "anxan_u", "caro_u", "loroxan_u", "lut_u", "neoxan_u", "vioxan_u", "zaxan_u", "lut_u"}
cofactors = {"rhodopsin_s", "nad_c", "nadh_c", "nadp_c","nadph_c",  "btn_c", "thmmp_c", "fad_c", "gthrd_c"}
lipids = {}
res = {"rna": rna, "dna": dna, "carbs": carbs, "acids": acids, "pigments": pigments, "cofactors": cofactors, "lipids": lipids}
all_ids = set([reactant.id for reactant in model.reactions.Biomass_Cvu_auto_DASH_.reactants])
counted = set()
for key, value in res.items():
    res[key] = {}
    for component in value:
        res[key][component] = 0
for reactant in model.reactions.Biomass_Cvu_auto_DASH_.reactants:
    if "R" not in reactant.formula:
        st = abs(reactant.formula_weight * model.reactions.Biomass_Cvu_auto_DASH_.metabolites[reactant] /1000)
        if reactant.id == "atp_c":
            st = abs(reactant.formula_weight * (model.reactions.Biomass_Cvu_auto_DASH_.metabolites[reactant] - model.reactions.Biomass_Cvu_auto_DASH_.metabolites[model.metabolites.h2o_c])/1000)
        for macro, val in res.items():
            if reactant.id in val.keys():
                res[macro][reactant.id] = st
                counted.add(reactant.id)
        if reactant.id.startswith("tag") or reactant.id.startswith("pai") or reactant.id.startswith("pe") or reactant.id.startswith("pg") or reactant.id.startswith("asqd") or reactant.id.startswith("sqdg") or \
            reactant.id.startswith("dgts") or reactant.id.startswith("dgdg") or reactant.id.startswith("mgdg") or reactant.id.startswith("pchol")  or reactant.id.startswith("ttdca_h")  or reactant.id.startswith("whttdca_h"):
                res["lipids"][reactant.id] = st
                counted.add(reactant.id)

# %%
model.reactions.Biomass_Cvu_auto_DASH_.metabolites[model.metabolites.h2o_c]
# Out:
# -29.89

# %%
reactant.formula_weight * (model.reactions.Biomass_Cvu_auto_DASH_.metabolites[model.metabolites.atp_c] - model.reactions.Biomass_Cvu_auto_DASH_.metabolites[model.metabolites.h2o_c])/1000
# Out:
# -7.3124635303500005

# %%
sum(res['rna'].values()) - res['rna']["atp_c"]
# Out:
# 0.1321675035291605

# %%
all_ids-counted
# Out:
# {'ala_DASH_L_c',
#  'arg_DASH_L_c',
#  'asn_DASH_L_c',
#  'asp_DASH_L_c',
#  'cys_DASH_L_c',
#  'gln_DASH_L_c',
#  'glu_DASH_L_c',
#  'gly_c',
#  'h2o_c',
#  'his_DASH_L_c',
#  'ile_DASH_L_c',
#  'leu_DASH_L_c',
#  'lys_DASH_L_c',
#  'met_DASH_L_c',
#  'phe_DASH_L_c',
#  'pro_DASH_L_c',
#  'ser_DASH_L_c',
#  'thr_DASH_L_c',
#  'trp_DASH_L_c',
#  'tyr_DASH_L_c',
#  'val_DASH_L_c'}

# %%
total = 0
for key, value in res.items():
    print(f"{key}: {sum(value.values())}")
    total+= sum(value.values())
total
# Out:
# rna: 15.151555397519042
# dna: 0.005848351349321159
# carbs: 7.418985550416226
# acids: 0
# pigments: 0.026930809155602777
# cofactors: 0
# lipids: 0.4793661808741688
# 23.08268628931436

# %%
0.080+0.48+0.163+0.248+0.026+0.006
# Out:
# 1.003

# %%
0.006/1.023
# Out:
# 0.0058651026392961885

# %%
7.42/8.063
# Out:
# 0.9202530075654223

# %%
model.metabolites.starch300_h.formula_weight*0.103/1000
# Out:
# 5.012000113839999

# %%
1-0.54
# Out:
# 0.45999999999999996

# %%
model.reactions.Biomass_Chlamy_auto.metabolites
# Out:
# {<Metabolite atp_c at 0x252ba289220>: -92.4316,
#  <Metabolite h2o_c at 0x252ba3015b0>: -92.4,
#  <Metabolite alatrna_c at 0x252ba278340>: -0.866034824,
#  <Metabolite argtrna_c at 0x252ba278b20>: -0.47516955,
#  <Metabolite asntrna_c at 0x252ba2785b0>: -0.2145927,
#  <Metabolite asptrna_c at 0x252ba278dc0>: -0.2145927,
#  <Metabolite cystrna_c at 0x252ba29d9a0>: -0.007664025,
#  <Metabolite glntrna_c at 0x252ba2eb6d0>: -0.256744837,
#  <Metabolite glutrna_c at 0x252ba2eb0a0>: -0.256744837,
#  <Metabolite glytrna_c at 0x252ba2eb910>: -0.325721062,
#  <Metabolite histrna_c at 0x252ba301ee0>: -0.003832012,
#  <Metabolite iletrna_c at 0x252ba317340>: -0.103464337,
#  <Metabolite leutrna_c at 0x252ba3177f0>: -0.26057685,
#  <Metabolite lystrna_c at 0x252ba317d30>: -0.057480187,
#  <Metabolite mettrna_c at 0x252ba329100>: -0.007664025,
#  <Metabolite phetrna_c at 0x252ba36bd90>: -0.10729635,
#  <Metabolite protrna_c at 0x252ba37eeb0>: -0.149448487,
# ...
